# %% [markdown]
# - 569
#
#     Данные неплохо отбрасываются, модель игадывает отклонения лучше чем линейная интерполяция, но не равномерно. Точность лучше, чем у линейной
#
#
# - 601
#
#     Опять же, отклонений, не связаных с малым временем замера не наблюдается.
#
#
# - 1354
#
#     Выбросов нет, но модель сама решила устроить выбросы, в общем действительно аномально
#
#
# - 1567
#
#     Нулевой дебит, однако, посмотрев `restore_input` аномалий я не нашёл. Нас обманули?
#
#
# - 1602
#
#     Ну, сейчас модель ведёт себя хуже((( выбрасов особо нет.
#     Однако, время замера плановое совпадает с фактическим, хотя и всего час. Тем не менее это не похоже что влияет на дебит
#
#
# - 1628
#
#     Полная фигня, надо смотреть
#
#     Когда убрался выброс и изменился насос на правильный, калибровки стали ближе к единице (хорошо) снизилось качество модели (плохо) - калибровки восстанавливаются в форме "пилы" - может полка? нужно посмотреть
